# %% [markdown]
# ## Ülesanne
#
# Selle nädala teema on otsustuspuu, ülesanded on järgmised
#
# 1) Vaata videot: https://www.youtube.com/watch?v=LDRbO9a6XPU
#
# 2) Kui jäi segaseks, otsi veel internetist materjali, mis seletavad otsustuspuu algoritmi
#
# 3) Harjuta otsustuspuu algoritmi iirise datasetil

# %% [markdown]
# ### Esimene ülesanne
#
# **Vasta küsimustele**
#
# 1) Seleta lühidalt ja oma sõnadega, kuidas toimib otsustuspuu algoritm.
#
# 2) Video dummy data pealt: kuidas jaotuvad andmed siis, kui ma esimesena küsin "kas värv on punane?". Milliseid küsimusi peaks edasi küsima, et andmed õigesti ära jaotuksid?
#
# | Color        | Diam           | Label  |
# | ------------- |:-------------:| -----:|
# | Green     | 3| Apple |
# | Green     | 3   |   Apple |
# | Red | 1   |    Grape |
# | Red |1    |   Grape |
# | Yellow | 3      |   Lemon |
#
#
# 3) Seleta lühidalt ja oma sõnadega, mis on *gini impurity*

# %% [markdown]
# ## Teine ülesanne
#
# Siia lisa kõik huvitavad lingid/videod mida internetist leidsid

# %% [markdown]
# ## Kolmas ülesanne
#
# Vii läbi otsustuspuu algoritm irise datasetil. Andmed on juba sinule antud.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
import pandas as pd
import numpy as np
iris = load_iris()
X = pd.DataFrame(iris.data, columns=iris.feature_names)
y = pd.Categorical.from_codes(iris.target, iris.target_names)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1) #Tekib neli dataseti

# X_train - treeninginfo
# y_train - treeninglabel

#X_test - #test info
# y_test - #test labelid


#Idee:
#1) Vii läbi otsustuspuu algoritm X_train ja X_test peal
#2) Rakenda saadud otsutuspuud tabelil X_test
#3) Hinda algoritmi headust võrreldest tulemusi y_testiga

#Võid kasutada sklearn paketist DecisionTreed, võid ka ise valmis kirjutada

X_train
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 54                 6.5               2.8                4.6               1.5
# 108                6.7               2.5                5.8               1.8
# 112                6.8               3.0                5.5               2.1
# 17                 5.1               3.5                1.4               0.3
# 119                6.0               2.2                5.0               1.5
# ..                 ...               ...                ...               ...
# 133                6.3               2.8                5.1               1.5
# 137                6.4               3.1                5.5               1.8
# 72                 6.3               2.5                4.9               1.5
# 140                6.7               3.1                5.6               2.4
# 37                 4.9               3.6                1.4               0.1
#
# [112 rows x 4 columns]
